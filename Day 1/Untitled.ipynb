# %%
import numpy as np
import pandas as pd
import os
import pickle
import matplotlib
import matplotlib.pyplot as plt

# %%
ex_viz = pickle.load(open("ex_viz.sav","rb"))
ex_grouped_mean_long = pickle.load(open("D:\Python\data\ex_grouped_mean_long.sav","rb"))
#ex_viz = pickle.load(open("ex_viz.sav","rb"))

print(ex_viz.head())
print("\n")
print("---------------------")      
print("\n")      
ex_grouped_mean_long
# Out:
#    percent_house_crowded  percent_house_below_poverty  percent_16_unemployed  \
# 0                    7.7                         23.6                    8.7
# 1                    7.8                         17.2                    8.8
# 2                    3.8                         24.0                    8.9
# 3                    3.4                         10.9                    8.2
# 4                    0.3                          7.5                    5.2
#
#    percent_25_without_diploma  percent_dependent  per_capita_income  \
# 0                        18.2               27.5                  0
# 1                        20.8               38.5                  0
# 2                        11.8               22.2                  1
# 3                        13.4               25.5                  1
# 4                         4.5               26.2                  1
#
#    hardship_index
# 0            39.0
# 1            46.0
# 2            20.0
# ...

# %%
ex_grouped_mean_wide = pickle.load(open("D:\Python\data\ex_grouped_mean_wide.sav","rb"))
ex_grouped_mean_wide
# Out:
# metric             hardship_index  percent_16_unemployed  \
# per_capita_income
# 0                       66.640000              18.810000
# 1                       18.910946               9.146429
#
# metric             percent_25_without_diploma  percent_dependent  \
# per_capita_income
# 0                                   26.092000          38.834000
# 1                                   10.042857          30.153571
#
# metric             percent_house_below_poverty  percent_house_crowded
# per_capita_income
# 0                                    26.780000               6.288000
# 1                                    12.739286               2.478571

# %%
plt.hist(ex_viz["percent_house_below_poverty"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(ex_viz["percent_house_below_poverty"], bins = 25)
plt.xlabel("percent_house_below_poverty")
plt.ylabel("Frequency")
plt.title("Percent House below Poverty Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(ex_viz["percent_dependent"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(ex_viz["percent_dependent"], vert= False)
plt.xlabel("Percent Dependent")
plt.title("Percent Dependent distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ex_true_means = ex_grouped_mean_long.query('per_capita_income == 1')[['metric','mean']]
print(ex_true_means)
# Out:
#                          metric       mean
# 1         percent_house_crowded   2.478571
# 3   percent_house_below_poverty  12.739286
# 5         percent_16_unemployed   9.146429
# 7    percent_25_without_diploma  10.042857
# 9             percent_dependent  30.153571
# 11               hardship_index  18.910946

# %%
ex_bar_labels = ex_true_means['metric']   
ex_bar_heights = ex_true_means['mean']    
ex_num_bars = len(ex_bar_heights)
ex_bar_positions = np.arange(ex_num_bars)

# %%
plt.bar(ex_bar_positions, ex_bar_heights)
plt.xticks(ex_bar_positions, ex_bar_labels, rotation = 90)
plt.ylabel('Mean values')
plt.title('Chicago Exercise Means')  #<- add plot title
plt.show()

# %%
# Adjust figure size before plotting.
plt.figure(figsize = (20, 15)) 
plt.bar(ex_bar_positions, ex_bar_heights)
plt.xticks(ex_bar_positions, ex_bar_labels)
plt.ylabel('Mean values')
plt.title('Chicago Exercise Means')  #<- add plot title
plt.show()

# %%
plt.scatter(ex_viz['percent_16_unemployed'],
            ex_viz['hardship_index'],
           marker = 'X')
plt.xlabel('percent_16_unemployed')                
plt.ylabel('hardship_index')
plt.title('Percent 16 Unemployed vs Hardship Index Distribution') 
plt.show()

# %%
plt.hist(ex_viz['percent_house_below_poverty'], facecolor = "lightcoral")
plt.xlabel('percent_house_below_poverty')          #<- label x-axis
plt.ylabel('Frequency')                            #<- label y-axis
plt.title('Count of Percent House below Poverty')  #<- add plot title
plt.show()

# %%
plt.figure(figsize= (15,10))
plt.bar(ex_bar_positions, ex_bar_heights, color = "thistle")
plt.xticks(ex_bar_positions, ex_bar_labels)
plt.ylabel('Mean values')
plt.title('Chicago Means')  
plt.show()

# %%
plt.scatter(ex_viz['percent_16_unemployed'],ex_viz['hardship_index'],marker = 'X',c = "firebrick")
plt.xlabel('percent_16_unemployed')                
plt.ylabel('hardship_index')
plt.title('Percent 16 Unemployed vs Hardship Index Distribution') 
plt.show()

# %%
ex_color_dict = {0 : 'darkorange', 1:'skyblue'}
color = ex_viz['per_capita_income'].map(ex_color_dict)
color.head()
# Out:
# 0    darkorange
# 1    darkorange
# 2       skyblue
# 3       skyblue
# 4       skyblue
# Name: per_capita_income, dtype: object

# %%
plt.scatter(ex_viz['percent_16_unemployed'], ex_viz['hardship_index'], c = color, alpha = 0.6)
plt.xlabel('percent_16_unemployed')                
plt.ylabel('hardship_index')
plt.title('Percent 16 Unemployed vs Hardship Index Distribution') 
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-darkgrid')

# %%
# Use seaborn-darkgrid style in matplotlib.
plt.scatter(ex_viz['percent_16_unemployed'], ex_viz['hardship_index'], c = color, alpha = 0.6)
plt.xlabel('percent_16_unemployed')                
plt.ylabel('hardship_index')
plt.title('Percent 16 Unemployed vs Hardship Index Distribution') 
plt.show()

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.titlesize'] = 15

# %%
# Use seaborn-darkgrid style in matplotlib.
plt.scatter(ex_viz['percent_16_unemployed'], ex_viz['hardship_index'], c = color, alpha = 0.6)
plt.xlabel('percent_16_unemployed')                
plt.ylabel('hardship_index')
plt.title('Percent 16 Unemployed vs Hardship Index Distribution') 
plt.show()

# %%
plt.rcdefaults()

# %%
plt.violinplot(ex_viz['percent_dependent'], showmeans = False, showmedians = False)
plt.show()

# %%
plt.violinplot(ex_viz['percent_dependent'], vert = False, showmeans = False, showmedians = False)
plt.xlabel('percent_dependent') 
plt.title('Percentage of dependents distribution')  
plt.show()
